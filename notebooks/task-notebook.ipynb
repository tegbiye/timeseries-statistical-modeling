# %%
# Import library
import pandas as pd

# %%
# Create the data
data = [
    ("1973-10-01","OPEC Oil Embargo","OPEC embargo leading to oil crisis"),
    ("1979-01-01","Iranian Revolution","Supply disruption, price spike"),
    ("1980-01-01","Oil Glut","Oversupply, price decline"),
    ("1985-01-01","OPEC Policy Change","Increased supply, price collapse"),
    ("1990-08-01","Iraqi Invasion of Kuwait","Gulf War, price shock"),
    ("2008-01-01","Financial Crisis","Demand drop, price fall"),
    ("2009-01-01","OPEC Production Cut","Cut output, price rebound"),
    ("2014-01-01","2010s Oil Glut","Shale boom, price decline"),
    ("2014-06-01","Saudi Market Flooding","Increased Saudi production, low prices"),
    ("2018-11-01","U.S. Sanctions on Iran","Supply concerns, price rise"),
    ("2020-03-01","Russia-Saudi Price War","Price war, sharp decline"),
    ("2020-03-01","COVID-19 Pandemic","Demand shock, negative prices"),
    ("2021-01-01","Energy Demand Surge","Recovery, price increase"),
    ("2022-02-01","Russian Invasion of Ukraine","Supply fears, high prices"),
]

# %%
# Convert to DataFrame
df = pd.DataFrame(data, columns=["Date","Event","Description"])

# %%
# Save as CSV
file_path = "../data/oil_market_events.csv"
df.to_csv(file_path, index=False)
